# %%
import pandas as pd

# %%
result = pd.read_csv('csv_input/nyse.csv')
result.fillna('0')
# Out:
#      Symbol                                               Name LastSale  \
# 0       DDD                             3D Systems Corporation    17.18
# 1       MMM                                         3M Company   200.38
# 2      WBAI                                    500.com Limited     7.17
# 3      WUBA                                        58.com Inc.    61.71
# 4      EGHT                                            8x8 Inc     18.2
# 5       AHC                              A.H. Belo Corporation     4.75
# 6      ATEN                                 A10 Networks, Inc.     5.93
# 7       AAC                                 AAC Holdings, Inc.      6.9
# 8       AIR                                          AAR Corp.    44.59
# 9       AAN                                 Aaron&#39;s,  Inc.    48.91
# 10      ABB                                            ABB Ltd    21.21
# 11      ABT                                Abbott Laboratories    68.14
# ...

# %%
result.head()
# Out:
#   Symbol                    Name  LastSale     MarketCap  ADR TSO  IPOyear  \
# 0    DDD  3D Systems Corporation     17.18  1.959040e+09      NaN      NaN
# 1    MMM              3M Company    200.38  1.175456e+11      NaN      NaN
# 2   WBAI         500.com Limited      7.17  3.029700e+08      NaN   2013.0
# 3   WUBA             58.com Inc.     61.71  9.101576e+09      NaN   2013.0
# 4   EGHT                 8x8 Inc     18.20  1.698458e+09      NaN      NaN
#
#               Sector                                         Industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4         Technology                                     EDP Services
#
#                         Summary Quote  Unnamed: 9
# ...
